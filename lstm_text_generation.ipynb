# %% [markdown]
# <a href="https://colab.research.google.com/github/Juliogallinaro/Google_colab/blob/master/lstm_text_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Generates text from Nietzsche's writings.

# %%
# !pip install -q keras

# %%
'''Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

path = get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=10,
          callbacks=[print_callback])
# Out:
# corpus length: 600893
# total chars: 57
# nb sequences: 200285
# Vectorization...
# Build model...
# Epoch 1/10
# 200285/200285 [==============================] - 141s 702us/step - loss: 2.0119
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "t to
# myself, as is sufficiently agreeabl"
# t to
# myself, as is sufficiently agreeable the so the reason the find the some of the man and supposity of the so the something the prope of the reason the man what the so the some of the prope of the reasons of the prope of the reaple to the reason the so the some of the so the man the some of the so the so the so the state of the reason the prope with the so the prope of the reason the most and a prope the world and so the pressions in
# ----- diversity: 0.5
# ----- Generating with seed: "t to
# myself, as is sufficiently agreeabl"
# t to
# myself, as is sufficiently agreeable the morality in for one fam a madiation and in the for one has be not south, on a wer as in the inderitions and the world and the reaplations and man in the constitus in for for the strank the agestic some to a knowledge of the consiits and pitity of cilluct to the
# considewions that the finstericate that good and the worth and
# constions in the, the anter and a perhaps to the awistor the really w
# ----- diversity: 1.0
# ----- Generating with seed: "t to
# myself, as is sufficiently agreeabl"
# t to
# myself, as is sufficiently agreeable. the
# outerved sermounss and nif.
# is wathout an the all so the funcourality, and the pressemations, puthes in worction to" hither arative immakiclallffences of
# difedictapioud in it
# only that subel, that redirional himstllating and the very is not same and reditions," langaths is except
# on sny it in1
# impatably unwillody im ratives as"oum to i fenseleth
# have,
# savermooverblitevory stamathanting le h
# ----- diversity: 1.2
# ----- Generating with seed: "t to
# myself, as is sufficiently agreeabl"
# t to
# myself, as is sufficiently agreeable colituokess surmalsanicred"-we
# a "not despice for churcoach supilsss instrand the amition moreresian his
# thistouchtimst"sant cccions? samethiog of you pawnopects daptifal by thas
# -greaks, natuys to is a pititoned my on
# makes coss as
# evil the virtuane estion dock, dosmoribul imsurtocing thikher, neigs ie isane. hat, mankance evety on inrmpical" what the mish;iares, we a coulom; vot ceaternichyefo
# Epoch 2/10
# 200285/200285 [==============================] - 140s 700us/step - loss: 1.6388
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: " character"--it would simply be "will to"
#  character"--it would simply be "will to the morality of the propers and a man is a great a nothing that the still of the man is a greeks and the sense of the strength of the senses of the sense of the still to the sense of the morality of the and a still of the spirit of the man itself, in the sense of the man in the consequence of the subtle in the morality of the man and a something of the still and itself, and sensish of the sublica
# ----- diversity: 0.5
# ----- Generating with seed: " character"--it would simply be "will to"
#  character"--it would simply be "will to really and consequences and respicism and subself--to loves and man of the belief in long in the subtled and that which have in the exalge of thought lift of the sense and the spirit, the consciously and in a mistorition, and says consequation of is an ause have a interpt that it is we have sense of the thought in a subtle sense, in the as the morality is itself in the consequences and the spirit
# ----- diversity: 1.0
# ----- Generating with seed: " character"--it would simply be "will to"
#  character"--it would simply be "will to i sarred of something, at a his
# vacaings, and hold strack, the lakes; despropen" the world se--subblemst indefferentaduals, so-subbllyss to that morad an ambly dival wholl man of it ansay what we world unimeedly han has spenses, comunamenest, that possuded to conientions,
# groon.
#
# right in his us.
#
# 193. let quediatuadation. the catert
# interw eurtry
# that man, and palrood
# ccater moralless." a people
# ----- diversity: 1.2
# ----- Generating with seed: " character"--it would simply be "will to"
#  character"--it would simply be "will to properias ofecived and wepe theien: interst alwafferrous
#  with that thin strutticaga'a., through in eprry od spirinas, that they
# we aruse loftion, comencation. it?
# now spuponise--have  deact." orimde. of logical of shouls it--we the
# not kinction, throunc," too _
# emothe eegard poslde am"d an mititary.--is term ne)s mots from itself,
# atunkbeasableer its decs,
# for maristicks true senturors, this mla
# Epoch 3/10
# 200285/200285 [==============================] - 137s 686us/step - loss: 1.5461
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: ", and subservient to them
# for all help. "
# , and subservient to them
# for all help. it is always and and as the world of the contrary of the recognized and present and present of the subleming and and problem. the stand and philosophy of the contrary of the sublement and morality and and and and the suffered and in the contrary and present and in the contrary of the sense. the world of the power that the subleming the sublements of the sublement of the contrary of the confustion
# ----- diversity: 0.5
# ----- Generating with seed: ", and subservient to them
# for all help. "
# , and subservient to them
# for all help. the metaphysical finally soul of alleas of the anceal who have not as so conscience and with and find such and people and were the man his and who have
# desured in the problem of recognizes and in the same of the courary one condicalle of the sense, and distruntity and it always and the most always distinction of the do to the could the look the which is nature at an impossion of not what has seem
# ----- diversity: 1.0
# ----- Generating with seed: ", and subservient to them
# for all help. "
# , and subservient to them
# for all help. have
# asceflite as he can centurical lectude. his genuesen--bettemionavivened the mastch
# tent
# guiked--prew caularutations, in idea of
# men of a philosophy of his of, is refuty--it recognigines is come corrects thanterindd wantity, good whele wasing are greeks belesse in accumed takes a way oself of what, natualed but autdual man, butly men what beings accumations sould milit 3folly, one's maryard in
# ----- diversity: 1.2
# ----- Generating with seed: ", and subservient to them
# for all help. "
# , and subservient to them
# for all help. that
# favil too know for contunc oponiu abom, our their inative unstandum
# head the
# standfulty, in fiouyty, ffathy,
# and which its
# revivally sare intellect unhy
# a bralitusmed and in much unabitunt of
# simant,
# abone abooy thing and law (brathouw of
# sesulemly one speakful;
# builled, bun bap tover,
# "orden aniveats aboun wly they would men only ie than and dery, the our so in this "prekerly of
# it samete an
# Epoch 4/10
# 200285/200285 [==============================] - 138s 687us/step - loss: 1.5031
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: ", on the contrary, to make a festival to"
# , on the contrary, to make a festival to the moralists and and in the subject of the most supposition of the subject of the strange the possible of the subject of the stand the stand the stand the most supposition of the stand of the subject of the completed to be well a subject of the possible the stand the spirituality of the possible and the subject of the conscience of the self-dell--the prosent and even the stanger to the possible
# ----- diversity: 0.5
# ----- Generating with seed: ", on the contrary, to make a festival to"
# , on the contrary, to make a festival to the emotion of supposing and natural palsity, the part the pain of the constituted, it is a fact that is the position and do as in this desire the recording the ears and about even in the recomes the truth the contrary as a law of into the most such our the present his advanced, more prodict and an hise and the most learn in all former to himself in the result of women again may as the bad and su
# ----- diversity: 1.0
# ----- Generating with seed: ", on the contrary, to make a festival to"
# , on the contrary, to make a festival to comple: on his hant. i long let a
# light folliver causanion of nowangee compalmsed to same that and cor, only and ar certain aessulst i make writer in this diction--goar in the amigance for the hold evolved, apowiesfogrent
# as themselved donly only them all fatharmed it
# is such, on the 'itof.t masten--our moraless, men have some does this kilistse), naturally. but which here as ebozait dow him is t
# ----- diversity: 1.2
# ----- Generating with seed: ", on the contrary, to make a festival to"
# , on the contrary, to make a festival to anc the entidicepsal eabill, gavile acc we gars yler--you: natov: therefort atono sairly an elbous presend" has, our single certainty, to be our evenct of full si-burcan, who re=trachion: why realifily on or
# them is purole, how this light
# owly its wollaying the have mo, ens guike-pexking affol they the
# fendem onnened thaticoureming, unpood. an inn"criel reterpsed demons great belreine good: plais
# Epoch 5/10
# 200285/200285 [==============================] - 137s 682us/step - loss: 1.4716
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "urch,
# characteristic of the type "free s"
# urch,
# characteristic of the type "free spirituality and and and and and in the strength that the strange, and the strength, and and in the strength, and the strength, and and and and the something of the respect to the strange and and and of the spirituality of the respect of the strength that it is an old and and and and and in the spiritual of the strength, and and and and and and and and and and and does not an order to the strange t
# ----- diversity: 0.5
# ----- Generating with seed: "urch,
# characteristic of the type "free s"
# urch,
# characteristic of the type "free secres the readiance and and and previlible and art and nature to the strength and an ansiders that an errone the imprein which the stame to the case of the sense--men of strengthing and souls men of the same and and respect of the science, the world the feelings to the above to the spirituality the one an age and the science and and as a conscience and in the religious the religious the first the
# ----- diversity: 1.0
# ----- Generating with seed: "urch,
# characteristic of the type "free s"
# urch,
# characteristic of the type "free sporthe of ourselve that ham to them, ever think, must disposed thetether for transificencl oy srirht man which or act asse, be,
# everlacsities;
# it other -will to
# forot? whoever fack of himself, for an atcelt to the ryposter corration markny, and bigdoed of cority. errors for were any
# threrial man and of view in conlatidit religious ancesth
# in that
# cololity taker; the mutuhe
# elped by the conceive of
# ----- diversity: 1.2
# ----- Generating with seed: "urch,
# characteristic of the type "free s"
# urch,
# characteristic of the type "free sppersoes dream than rise, is algoesking that. an potking muliver oulselve how of words! there man for instilitation, the previls agrean of the rathed disers. an respect cartion, allest thest somethical, howimal reacheaks. foreest, down weres "every
# nomin us ar men. the consplime and pequably ever capobitations; the spirit wouthtterness
# gofal," of detiperatiar
# self
# of justef--it reverin-unet upseef
# Epoch 6/10
# 200285/200285 [==============================] - 139s 692us/step - loss: 1.4492
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "bition, close to such problems, and as
# i"
# bition, close to such problems, and as
# it is a senses of the problem of the soul of his matter in the conscience of the soul of the such as the intellectual moral profound the senses of the deligious sensed to the sense of the problem of the world and the sense of the senses of the sense of the such and in the such a problem of such a personal and sense of all the individing of the senses of the some and of the such a problem of the sou
# ----- diversity: 0.5
# ----- Generating with seed: "bition, close to such problems, and as
# i"
# bition, close to such problems, and as
# it is to have so such more personal because the something itself; barking in the self-pallare of the develops of self-result a serrous, or he not alasour and to have it is a parts are about certain that is somether is has been our externess of exceptions as an uninterrouse the to hatred to be former, in the starce of his developing and the serrous-cold every own moral propering his men of which he
# ----- diversity: 1.0
# ----- Generating with seed: "bition, close to such problems, and as
# i"
# bition, close to such problems, and as
# itself
# and though hardless to every or aedles: his philosophers human pitticls, and highest how
# with the crear, have "frounds in others an art what self-domening in permose to pleate. in the
# pleasure, and philosophical pposen: the strived. metaber
# ratify-entifical--itself, tould the happylist of the advance experiential and explicitimation instinct, that will dotoy; by the abasy. to it yabliness wh
# ----- diversity: 1.2
# ----- Generating with seed: "bition, close to such problems, and as
# i"
# bition, close to such problems, and as
# ilse" is would: in a plate, the call it bast naturily, and
# who, wishomfine syntightming faces.
#
# onhy, "absventeriyual, mituabity we doman "inteelect on forhes?
#
#
# 5n a do
# of alination."
# the syeth--aven who"
# with that overjood,
# stanc
# our evancalcyation, as
# the usiousle
# at that read, and position of sery probably how," than this litts uinhap," as the mens on the philosophy witive causa, read antaquab
# Epoch 7/10
# 200285/200285 [==============================] - 138s 690us/step - loss: 1.4339
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "r, as a result of heredity or natural di"
# r, as a result of heredity or natural discordition of the constantly present the same the constant the senses and the something the consideration of the constantly the present the present
# the present the present that the senses and of the senses of the spiritual morality of the such a such as the master of the consequently and the self-delight to the master, and the senses to the senses to the constant and senses to the constantly the s
# ----- diversity: 0.5
# ----- Generating with seed: "r, as a result of heredity or natural di"
# r, as a result of heredity or natural distance, the such into he extrisions of the particularly the sensible to the soul and the exceptions and that self and present a sort of the such places to the constrain that there a man has as a pround
# mankind. the entire to a laws of which the constant and a life and to far as the historing the first present of the contradian such self-delight and consequently the significance of the server and a
# ----- diversity: 1.0
# ----- Generating with seed: "r, as a result of heredity or natural di"
# r, as a result of heredity or natural discholog"--that deriverfulness:--will
# have confritin to
# wish of fases:
#
#
# 4 self-remucse and to the bost precious conduct people at something is even
# a law, the uneza, is them has have a cruse of
# welf makess uutor, much despairibl to make it is bather
# dokes them!"hto showns onifoh, endieters at his is the doubted only who dater of the still time concerned
# as the midersud: that the operi"tion.
#
# 2ous
# ----- diversity: 1.2
# ----- Generating with seed: "r, as a result of heredity or natural di"
# r, as a result of heredity or natural discosiin knowledgent
# rishe with
# relugur is condited of believed is a metayer, -others
# helh
# we,
# step ideas the circoseblies; that a philosophy, hought to cisions undleast"-pove and ts
# bea. [hac eries ussposing one's a
# sortucte y -cotions of a grees, he it
# the
# "from ideat" are orounated reriretity; that type and still
# rimmallys:--he to nowlike development animalion say even that conidially it were
# ro
# Epoch 8/10
# 200285/200285 [==============================] - 134s 668us/step - loss: 1.4186
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "er, a strange, still unconquered
# enemy:-"
# er, a strange, still unconquered
# enemy:--the self-expless of the strengt of the stand of the stand the self-experience to the self-endition of the stand the strength, and and the strong of the soul of the stand the strength of the same the strange of the strength of the stand of the stands and desperation of the same the struggle and deperion of the soul of and and and the struggle and as the self-even to the soul of the strange of the
# ----- diversity: 0.5
# ----- Generating with seed: "er, a strange, still unconquered
# enemy:-"
# er, a strange, still unconquered
# enemy:--the prost in the self--our could be ancient the most him of the skepticlent and shares, and the standard and love of the extent the end, the world become and reason and free spirit which understanding it in the spirit of one strict, the self almost imperaplary, the self-natured or such and the mittical doubt of the subtle should not a struggle of one of "freedom of the self-conscience of the stan
# ----- diversity: 1.0
# ----- Generating with seed: "er, a strange, still unconquered
# enemy:-"
# er, a strange, still unconquered
# enemy:-wit intepreses the fres of attance; it can be to be justice oruting apparsal does not wkine be reknine it is ownest peacet its own every wonine of the new"--their milcus
# as "sance new-dant,
# suffering,--only we leverous
# healis ba soul assent conception--to be beareful different
#
# all and actly: hi was be in greated something personalire thatchimently betraphfitate men as nor hes respect of thespehy
# ----- diversity: 1.2
# ----- Generating with seed: "er, a strange, still unconquered
# enemy:-"
# er, a strange, still unconquered
# enemy:-hir, he weran
# puriously friend its
# origin, from plegare-dean-men to it
# say and tend by precisely
# puredoken:
# "hourout even againsts--he even pallar pot bynets may only freedy much in callarify, new alone than modestne)s on klorhare on for their statemently,
# while aet then, on the sidg, on hishemently reat andagratonly.--the highest poverriast; luin
# teastment cesstitionas
# of skitlreness, as nothen,"
# Epoch 9/10
# 200285/200285 [==============================] - 134s 671us/step - loss: 1.4074
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: " tears and lacerates himself with
# his ow"
#  tears and lacerates himself with
# his own contemption of the most sublime of the man who has a soul of the proper of the sense"--the man is the world of the man who has to all the inversion the world of the man will be the sense, which is the present of the conscience of the sublime of the man is all the man who dell the man is the feelings of the contemption of the will and the man who has to some the sense, the man who have the streng
# ----- diversity: 0.5
# ----- Generating with seed: " tears and lacerates himself with
# his ow"
#  tears and lacerates himself with
# his own advances, in the will to the sublime the conversable ciecement of the subseance of a proper is the little consequently and strength,
# the present something which the man of connection of subjective, and the self-mands in the called and person is the sublime in its turd of the contemptifical morals one's with sugnority the extention, and among the confusion
# of the influence of man will distinction
# ----- diversity: 1.0
# ----- Generating with seed: " tears and lacerates himself with
# his ow"
#  tears and lacerates himself with
# his own case
# where forting it can knowleted
# the posse--will be certenal
# wond not the man what well at lose of nomans sive) as it can late a very so praisic of murent opposite flut most upsele
# find neither, and feel at this and d alratism heifther,
# they that imull. refutly.
# such freedom blund, but say pand a master, been camersguate to theis with the man for civerlitate priecem, henverrednesseving which
# ----- diversity: 1.2
# ----- Generating with seed: " tears and lacerates himself with
# his ow"
#  tears and lacerates himself with
# his own usendful an armists which may old as a bewbleonizing in thrownen, medarcely. belied all that in ewisy! man is, from which my seifictrounceld witering great
# incated seas, thr dave," the
# can suffering the enrry elstains the
# plass and howev ir, if their sublima not salknt, i to indile,
# to the verouy of whleishace the history of resains
# ach, and shouldeven, suff requireints)!--bothy," not
# the asings
# Epoch 10/10
# 200285/200285 [==============================] - 133s 664us/step - loss: 1.3969
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "n tour de force, a slight ostentation an"
# n tour de force, a slight ostentation and and in the soul of the supersition of the such and the self-distrust of the sense of the sense of an and and the sense of the feeling of the soul of the sensualists of the self-distrust of the profound to the same and the same profound to the same and the profound the same to the self-desire to the conscience of the contrary, and the most sensualists of the sentiments of the contince of the sens
# ----- diversity: 0.5
# ----- Generating with seed: "n tour de force, a slight ostentation an"
# n tour de force, a slight ostentation and reason and sould, which forginar contrary, on the belief in the proof of foundancy. the last and this sense of the same and to believe the completion in mankind to the sacrifice of the first the most acts and part of such a part of morality is at a revenge of his self religious himself in the power
# of him and the same and itself, is origie of anti-the sold to the recognition of the freedd in the
# ----- diversity: 1.0
# ----- Generating with seed: "n tour de force, a slight ostentation an"
# n tour de force, a slight ostentation and had man whosekty. there love how of the by, which pitured on the regald to the most cluction for others, tooe, such inveenres is machume than thrownest from on the
# hunder doistitar and rights the propers
# one must falsely," onle now wiokge, antthe is the such
# that aims to the experient of at the heart,
# and fundamely forgh, respecteal
# intellect , socialing him" and love," as an opposite that it be
# ----- diversity: 1.2
# ----- Generating with seed: "n tour de force, a slight ostentation an"
# n tour de force, a slight ostentation and datter morg knowwd og ranken, at disciplenis.
# and old just and
# love.--eusope to the sight of things
# higher depected, everything owing to
# rearentod and chaprianisness; hen preferistics
# and which
# much omey mince vaitco risk andomir toodd, there hulses betaling, thele,
# my nor untence liy eaest and itself---oblibves,
# in the
# useive, in
# civasp thoughts !" sick of our rengple; the time tendnent of exer
